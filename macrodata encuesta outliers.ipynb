# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
encuesta = pd.read_csv("./data/ENCUESTA_2_Responses.csv")

# %%
encuesta.head()
# Out:
#               Date Collected                  Date Sent  Duration (seconds)  \
# 0  2018-03-13 18:20:11 -0600  2018-03-13 18:20:12 -0600                 430
# 1  2018-03-13 18:13:35 -0600  2018-03-13 18:18:07 -0600                 574
# 2  2018-03-13 18:10:10 -0600  2018-03-13 18:10:13 -0600                 374
# 3  2018-03-13 17:59:57 -0600  2018-03-13 17:59:59 -0600                 308
# 4  2018-03-13 17:46:39 -0600  2018-03-13 18:22:25 -0600                 261
#
#          User   Latitude   Longitude Por favor marca tu ubicación en el mapa  \
# 0  Electoral2  29.082672 -110.926628                   29,082624,-110,926614
# 1  Electoral4  29.081686 -110.928238                   29,081691,-110,928230
# 2  Electoral2  29.082623 -110.926918                   29,082775,-110,926764
# 3  Electoral3  29.081496 -110.927217                   29.081585,-110.927134
# 4  Electoral1  29.081359 -110.927233                   29,081484,-110,927491
#
#     Municipio  Sección  Manzana  ...  \
# ...

# %%
encuesta.describe()
# Out:
#        Duration (seconds)     Latitude    Longitude       Sección  \
# count         1210.000000  1210.000000  1210.000000   1210.000000
# mean           482.340496    28.844368  -110.032471    838.488430
# std            271.279110     3.136022    10.145236   1031.157215
# min              0.000000     0.000000  -115.009377     17.000000
# 25%            330.000000    27.483297  -110.995084    379.000000
# 50%            454.500000    29.083378  -110.941782    730.000000
# 75%            614.000000    30.626073  -109.935468   1142.000000
# max           3253.000000    32.463307     0.000000  21103.000000
#
#            Manzana  \
# count  1210.000000
# mean     68.455372
# std     305.858217
# min       1.000000
# 25%      15.000000
# 50%      30.000000
# 75%      57.000000
# max    9999.000000
#
#        Sylvana Beltrones y Manuel Ignacio "Maloro" Acosta - PRI PVEM PANAL  \
# count                                        1073.000000
# ...

# %%
encuesta.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Duration (seconds)'}>,
#         <AxesSubplot:title={'center':'Latitude'}>,
#         <AxesSubplot:title={'center':'Longitude'}>],
#        [<AxesSubplot:title={'center':'Sección'}>,
#         <AxesSubplot:title={'center':'Manzana'}>,
#         <AxesSubplot:title={'center':'Sylvana Beltrones y Manuel Ignacio "Maloro" Acosta - PRI PVEM PANAL'}>],
#        [<AxesSubplot:title={'center':'Antonio "Toño" Astiazaran y Leticia Cuesta - PAN PRD Movimiento Ciudadano'}>,
#         <AxesSubplot:title={'center':'Lily Tellez y Alfonso Durazo - MORENA PES PT'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
encuesta.boxplot(by='User', column=['Duration (seconds)'], figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Duration (seconds)'}, xlabel='User'>
